# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
f = open('../simulator/simulator/sim/out.txt')

# %%
a = []
for l in f:
    a.append(int(l))

# %%
plt.plot(a,marker=".")
plt.plot()
# Out:
# []
