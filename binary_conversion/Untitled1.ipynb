# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
g = open("test.txt", 'w')

# %%
for i in range(10000):
    g.write(str((i-100.5) * 0.01))
    g.write('\n')
g.write('0.0\n')
# Out:
# 4

# %%
f = open('../simulator/simulator/sim/out.txt')

# %%
a = []
for l in f:
    a.append(int(l))

# %%
plt.plot(a,marker=".")
plt.plot()
# Out:
# []
